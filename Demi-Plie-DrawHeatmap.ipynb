# %%
from scipy import stats, integrate
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
xload = np.load('allDemiPlieXList.npy')
print(xload)
print(len(xload))
yload = np.load('allDemiPlieYList.npy')
print(yload)
print(len(yload))

#flatten the list of lists to a single list:
y = [item for items in yload for item in items]

x = [item for items in xload for item in items]
# Out:
# [[0.533876 0.53184  0.497124 ... 0.495006 0.497016 0.529765]
#  [0.533889 0.531827 0.497119 ... 0.491014 0.495044 0.529787]
#  [0.531914 0.529859 0.495115 ... 0.491009 0.495051 0.52979 ]
#  ...
#  [0.51757  0.517534 0.488964 ... 0.482864 0.482809 0.513428]
#  [0.517528 0.517547 0.488968 ... 0.482844 0.482795 0.513397]
#  [0.517503 0.517545 0.488962 ... 0.4829   0.482856 0.513411]]
# 869
# [[-0.363431 -0.44503  -0.445069 ... -0.818631 -0.815777 -0.802143]
#  [-0.363465 -0.445031 -0.442516 ... -0.821238 -0.815861 -0.804894]
#  [-0.363491 -0.445043 -0.44506  ... -0.821167 -0.815811 -0.802165]
#  ...
#  [-0.412535 -0.472545 -0.475172 ... -0.818387 -0.813028 -0.802128]
#  [-0.417943 -0.477851 -0.477915 ... -0.815869 -0.81298  -0.799504]
#  [-0.41789  -0.483292 -0.483333 ... -0.818364 -0.812993 -0.799372]]
# 869

# %%
#ax = sns.kdeplot(x = x,y = y,cmap = "Blues", shade = True,gridsize = 200)
fig, ax = plt.subplots(figsize=(8,8))
ax = sns.kdeplot(x = x,y = y,cmap = "Blues", shade = True)

#plotKDE
ax.set_frame_on(False)
plt.title('Demi-Plie KDE')
plt.xlim(0,1)
plt.ylim(-1,0)
plt.axis('on')
plt.show()

# %%
sns.displot(x=x,y=y, kind = "kde")
