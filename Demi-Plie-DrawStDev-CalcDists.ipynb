# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
xMeanloaded = np.load('Demi-PlieMeanX.npy')
yMeanloaded = np.load('Demi-PlieMeanY.npy')
stdDevX = np.load('Demi-PlieStdDevX.npy')
stdDevY = np.load('Demi-PlieStdDevY.npy')

# %%
print(xMeanloaded)
print(yMeanloaded)
xMeanList = list(xMeanloaded)
yMeanList = list(yMeanloaded)
print(xMeanList)
print(yMeanList)

print(stdDevX)
print(stdDevY)
# Out:
# [0.51551588 0.51600105 0.48170916 0.45752281 0.46730601 0.54988367
#  0.57434555 0.56927812 0.51744389 0.49434375 0.46371047 0.50294312
#  0.54062762 0.57374258 0.53731369 0.50792097 0.52284376 0.49802083
#  0.533113   0.56564105 0.56263865 0.52911201 0.47621932 0.4765224
#  0.51061463]
# [-0.35125851 -0.42133278 -0.4215729  -0.49636282 -0.55768396 -0.42049227
#  -0.49340649 -0.55605029 -0.56296368 -0.56344682 -0.67257255 -0.76727084
#  -0.56258461 -0.67041066 -0.76710647 -0.34376515 -0.3431918  -0.35484782
#  -0.35389452 -0.79166086 -0.78214796 -0.7747197  -0.79209326 -0.78517321
#  -0.77477489]
# [0.5155158757192178, 0.5160010471806675, 0.4817091622554661, 0.4575228089758342, 0.46730600805523614, 0.5498836708860758, 0.5743455500575373, 0.569278120828539, 0.5174438929804369, 0.49434375373993095, 0.4637104706559263, 0.5029431196777906, 0.5406276156501733, 0.5737425753739934, 0.5373136915995393, 0.5079209712313003, 0.5228437629459146, 0.4980208250863058, 0.5331130046029917, 0.5656410483314159, 0.5626386455696208, 0.5291120057537394, 0.4762193199079402, 0.4765224039125427, 0.5106146283084011]
# [-0.35125850632911426, -0.4213327813578831, -0.42157289528193337, -0.49636281818181793, -0.5576839551208282, -0.42049227042577625, -0.4934064856156506, -0.5560502865362483, -0.5629636766398157, -0.5634468193325656, -0.6725725512082857, -0.7672708400460314, -0.5625846121979283, -0.6704106570771001, -0.7671064729574226, -0.3437651518987339, -0.3431917997698504, -0.35484782163406225, -0.35389451553509743, -0.7916608642117383, -0.7821479620253148, -0.7747197042577675, -0.7920932600690452, -0.785173208285385, -0.7747748872266977]
# [0.02519256 0.02542178 0.02502622 0.02528518 0.0257216  0.02632875
#  0.02848537 0.0280023  0.02556431 0.02513103 0.0237576  0.02552124
#  0.02615816 0.029307   0.02608875 0.02549152 0.02580312 0.02501494
#  0.02571488 0.02788136 0.04279885 0.02549842 0.02558853 0.0259794
#  0.02577096]
# [0.03381867 0.03127332 0.03108132 0.02879099 0.03039074 0.03133551
#  0.0292348  0.03197731 0.02993309 0.02957522 0.02859252 0.03177219
#  0.03012622 0.02929678 0.03160622 0.03358191 0.03392408 0.03391117
#  0.0342608  0.03123822 0.05531462 0.03194466 0.03164548 0.03124387
#  0.03213609]

# %%
#determine which features are close to 0 in value:
bones = [[0,1],[1,2],[2,3],[3,4],[1,5],[5,6],[6,7],[1,8],[8,12],[8,9],[9,10],[10,11],[11,24],[11,22],[22,23],[12,13],[13,14],[14,21],[14,19],[19,20],[0,16],[0,15],[15,17],[16,18]]
for bone in bones:
    if (xMeanList[bone[0]]<= 0.05 and yMeanList[bone[0]] <= 0.05):
        print("Less than 0.05 value for feature: ",xMeanList.index(xMeanList[bone[0]]))
    if(xMeanList[bone[1]]<= 0.05 and yMeanList[bone[1]] <= 0.05):
        print("Less than 0.05 for feature: ",xMeanList.index(xMeanList[bone[1]]))

# %%
bones = [[0,1],[1,2],[2,3],[3,4],[1,5],[5,6],[6,7],[1,8],[8,12],[8,9],[9,10],[10,11],[11,24],[11,22],[22,23],[12,13],[13,14],[14,21],[14,19],[19,20],[0,16],[0,15],[15,17],[16,18]]
print(len(bones))
def plotMeanCoordinates():
    fig, ax = plt.subplots(1, figsize=(10,10))
    plt.title('Demi-Plie Mean Skeleton')
    plt.xlim(0, 1)
    plt.ylim(-1, 0)
    sc = ax.scatter(xMeanList,yMeanList, s=10)
    counter=0
    for bone in bones:
        # code to not draw lines to features that were close to 0 values:
        #if(bone[0]==0 and bone[1]==16) or (bone[0]==16 and bone[1]==18):
            #continue
        ax.plot([xMeanList[bone[0]],xMeanList[bone[1]]],[yMeanList[bone[0]],yMeanList[bone[1]]],'orchid')      
plotMeanCoordinates()
# Out:
# 24

# %%
#to add the std dev values to the mean skeleton values:
print(xMeanloaded)
print(stdDevX)
stDevPlotPlusX = [x1+x2 for x1,x2 in zip(xMeanloaded,stdDevX)]
print(stDevPlotPlusX)
print(yMeanloaded)
print(stdDevY)
stDevPlotPlusY = [y1+y2 for y1, y2 in zip(yMeanloaded, stdDevY)]
print(stDevPlotPlusY)
# Out:
# [0.51551588 0.51600105 0.48170916 0.45752281 0.46730601 0.54988367
#  0.57434555 0.56927812 0.51744389 0.49434375 0.46371047 0.50294312
#  0.54062762 0.57374258 0.53731369 0.50792097 0.52284376 0.49802083
#  0.533113   0.56564105 0.56263865 0.52911201 0.47621932 0.4765224
#  0.51061463]
# [0.02519256 0.02542178 0.02502622 0.02528518 0.0257216  0.02632875
#  0.02848537 0.0280023  0.02556431 0.02513103 0.0237576  0.02552124
#  0.02615816 0.029307   0.02608875 0.02549152 0.02580312 0.02501494
#  0.02571488 0.02788136 0.04279885 0.02549842 0.02558853 0.0259794
#  0.02577096]
# [0.5407084359271016, 0.5414228234363112, 0.5067353856526907, 0.48280799347281617, 0.49302760578900934, 0.5762124159426791, 0.6028309232714321, 0.5972804176162573, 0.5430082041628121, 0.5194747793999134, 0.487468068028167, 0.5284643597292549, 0.5667857766709781, 0.6030495721406296, 0.5634024428083495, 0.5334124907075889, 0.5486468825362123, 0.5230357654974124, 0.5588278874261853, 0.5935224132330624, 0.605437493718163, 0.5546104300775385, 0.5018078471360103, 0.5025017991905438, 0.5363855932927957]
# [-0.35125851 -0.42133278 -0.4215729  -0.49636282 -0.55768396 -0.42049227
#  -0.49340649 -0.55605029 -0.56296368 -0.56344682 -0.67257255 -0.76727084
#  -0.56258461 -0.67041066 -0.76710647 -0.34376515 -0.3431918  -0.35484782
#  -0.35389452 -0.79166086 -0.78214796 -0.7747197  -0.79209326 -0.78517321
#  -0.77477489]
# [0.03381867 0.03127332 0.03108132 0.02879099 0.03039074 0.03133551
#  0.0292348  0.03197731 0.02993309 0.02957522 0.02859252 0.03177219
#  0.03012622 0.02929678 0.03160622 0.03358191 0.03392408 0.03391117
#  0.0342608  0.03123822 0.05531462 0.03194466 0.03164548 0.03124387
#  0.03213609]
# [-0.31743983525314323, -0.3900594591513341, -0.39049157379509736, -0.46757182700819677, -0.5272932114128576, -0.3891567574918675, -0.46417168258641994, -0.5240729749657238, -0.5330305850686236, -0.5338716028524, -0.6439800355967396, -0.7354986503030645, -0.5324583949218294, -0.6411138798920075, -0.7355002548777069, -0.31018324124254554, -0.30926771627977084, -0.32093664878244793, -0.3196337137754263, -0.7604226407062142, -0.7268333414919852, -0.742775045600393, -0.7604477784297791, -0.7539293421925009, -0.7426387975488216]

# %%
def plotStandardDevSkeletonPlus():
    fig, ax = plt.subplots(1, figsize=(10,10))
    plt.title('Demi-Plie Standard Deviation Skeleton Added')
    plt.xlim(0, 1)
    plt.ylim(-1, 0)
    sc = ax.scatter(stDevPlotPlusX,stDevPlotPlusY, s=10)
    #counter=0
    for bone in bones:
        ax.plot([stDevPlotPlusX[bone[0]],stDevPlotPlusX[bone[1]]],[stDevPlotPlusY[bone[0]],stDevPlotPlusY[bone[1]]],'orchid')
            
plotStandardDevSkeletonPlus()

# %%
#Save the standard deviation skeleton plus
import os
np.save(os.path.join('NumpyDemiPlie', 'DemiStdDevPlotPlusX.npy'), stDevPlotPlusX)
np.save(os.path.join('NumpyDemiPlie', 'DemiStdDevPlotPlusY.npy'), stDevPlotPlusY)
testX = np.load(os.path.join('NumpyDemiPlie','DemiStdDevPlotPlusX.npy'))
print(testX)
testY = np.load(os.path.join('NumpyDemiPlie','DemiStdDevPlotPlusY.npy'))
print(testY)
# Out:
# [0.54070844 0.54142282 0.50673539 0.48280799 0.49302761 0.57621242
#  0.60283092 0.59728042 0.5430082  0.51947478 0.48746807 0.52846436
#  0.56678578 0.60304957 0.56340244 0.53341249 0.54864688 0.52303577
#  0.55882789 0.59352241 0.60543749 0.55461043 0.50180785 0.5025018
#  0.53638559]
# [-0.31743984 -0.39005946 -0.39049157 -0.46757183 -0.52729321 -0.38915676
#  -0.46417168 -0.52407297 -0.53303059 -0.5338716  -0.64398004 -0.73549865
#  -0.53245839 -0.64111388 -0.73550025 -0.31018324 -0.30926772 -0.32093665
#  -0.31963371 -0.76042264 -0.72683334 -0.74277505 -0.76044778 -0.75392934
#  -0.7426388 ]

# %%
#to minus the std dev values from the mean skeleton values:
print(xMeanloaded)
print(stdDevX)
stDevPlotMinusX = [x1-x2 for x1,x2 in zip(xMeanloaded,stdDevX)]
print(stDevPlotMinusX)
print(yMeanloaded)
print(stdDevY)
stDevPlotMinusY = [y1-y2 for y1, y2 in zip(yMeanloaded, stdDevY)]
print(stDevPlotMinusY)
# Out:
# [0.51551588 0.51600105 0.48170916 0.45752281 0.46730601 0.54988367
#  0.57434555 0.56927812 0.51744389 0.49434375 0.46371047 0.50294312
#  0.54062762 0.57374258 0.53731369 0.50792097 0.52284376 0.49802083
#  0.533113   0.56564105 0.56263865 0.52911201 0.47621932 0.4765224
#  0.51061463]
# [0.02519256 0.02542178 0.02502622 0.02528518 0.0257216  0.02632875
#  0.02848537 0.0280023  0.02556431 0.02513103 0.0237576  0.02552124
#  0.02615816 0.029307   0.02608875 0.02549152 0.02580312 0.02501494
#  0.02571488 0.02788136 0.04279885 0.02549842 0.02558853 0.0259794
#  0.02577096]
# [0.49032331551133385, 0.4905792709250238, 0.45668293885824157, 0.4322376244788522, 0.44158441032146295, 0.5235549258294725, 0.5458601768436425, 0.5412758240408208, 0.4918795817980616, 0.4692127280799485, 0.4399528732836856, 0.4774218796263264, 0.5144694546293684, 0.5444355786073573, 0.5112249403907292, 0.48242945175501173, 0.4970406433556169, 0.4730058846751992, 0.5073981217797982, 0.5377596834297694, 0.5198397974210787, 0.5036135814299403, 0.45063079267987005, 0.4505430086345415, 0.48484366332400647]
# [-0.35125851 -0.42133278 -0.4215729  -0.49636282 -0.55768396 -0.42049227
#  -0.49340649 -0.55605029 -0.56296368 -0.56344682 -0.67257255 -0.76727084
#  -0.56258461 -0.67041066 -0.76710647 -0.34376515 -0.3431918  -0.35484782
#  -0.35389452 -0.79166086 -0.78214796 -0.7747197  -0.79209326 -0.78517321
#  -0.77477489]
# [0.03381867 0.03127332 0.03108132 0.02879099 0.03039074 0.03133551
#  0.0292348  0.03197731 0.02993309 0.02957522 0.02859252 0.03177219
#  0.03012622 0.02929678 0.03160622 0.03358191 0.03392408 0.03391117
#  0.0342608  0.03123822 0.05531462 0.03194466 0.03164548 0.03124387
#  0.03213609]
# [-0.3850771774050853, -0.4526061035644321, -0.4526542167687694, -0.5251538093554391, -0.5880746988287989, -0.451827783359685, -0.5226412886448812, -0.5880275981067729, -0.5928967682110079, -0.5930220358127312, -0.7011650668198319, -0.7990430297889983, -0.5927108294740272, -0.6997074342621927, -0.7987126910371384, -0.3773470625549223, -0.37711588325993, -0.3887589944856766, -0.38815531729476854, -0.8228990877172624, -0.8374625825586444, -0.806664362915142, -0.8237387417083114, -0.816417074378269, -0.8069109769045739]

# %%
def plotStandardDevSkeletonMinus():
    fig, ax = plt.subplots(1, figsize=(10,10))
    plt.title('Demi-Plie Standard Deviation Skeleton Subtracted')
    plt.xlim(0, 1)
    plt.ylim(-1, 0)
    sc = ax.scatter(stDevPlotMinusX,stDevPlotMinusY, s=10)
    #counter=0
    for bone in bones:
        ax.plot([stDevPlotMinusX[bone[0]],stDevPlotMinusX[bone[1]]],[stDevPlotMinusY[bone[0]],stDevPlotMinusY[bone[1]]],'orchid')
            
plotStandardDevSkeletonMinus()

# %%
#Save the standard deviation skeleton subtracted
import os
np.save(os.path.join('NumpyDemiPlie', 'DemiStdDevPlotMinusX.npy'), stDevPlotMinusX)
np.save(os.path.join('NumpyDemiPlie', 'DemiStdDevPlotMinusY.npy'), stDevPlotMinusY)
testX2 = np.load(os.path.join('NumpyDemiPlie','DemiStdDevPlotMinusX.npy'))
print(testX2)
testY2 = np.load(os.path.join('NumpyDemiPlie','DemiStdDevPlotMinusY.npy'))
print(testY2)
# Out:
# [0.49032332 0.49057927 0.45668294 0.43223762 0.44158441 0.52355493
#  0.54586018 0.54127582 0.49187958 0.46921273 0.43995287 0.47742188
#  0.51446945 0.54443558 0.51122494 0.48242945 0.49704064 0.47300588
#  0.50739812 0.53775968 0.5198398  0.50361358 0.45063079 0.45054301
#  0.48484366]
# [-0.38507718 -0.4526061  -0.45265422 -0.52515381 -0.5880747  -0.45182778
#  -0.52264129 -0.5880276  -0.59289677 -0.59302204 -0.70116507 -0.79904303
#  -0.59271083 -0.69970743 -0.79871269 -0.37734706 -0.37711588 -0.38875899
#  -0.38815532 -0.82289909 -0.83746258 -0.80666436 -0.82373874 -0.81641707
#  -0.80691098]

# %%
import pandas as pd
#Histograms

# %%
# first get a sample skeleton:
import os
bones = [[0,1],[1,2],[2,3],[3,4],[1,5],[5,6],[6,7],[1,8],[8,12],[8,9],[9,10],[10,11],[11,24],[11,22],[22,23],[12,13],[13,14],[14,21],[14,19],[19,20],[0,16],[0,15],[15,17],[16,18]]
DIR = "D:\openpose-1.5.0-binaries-win64-gpu-python-flir-3d_recommended\openpose-1.5.0-binaries-win64-gpu-python-flir-3d_recommended\DatasetPosePerDancer\Demi-Plie\Dancer15"

def plotSampleSkeleton():
    fig, ax = plt.subplots(1, figsize = (8,8))
    plt.title('Demi-Plie Skeleton Sample Match')
    plt.xlim(0,1)
    plt.ylim(-1,0)
    file_path = os.path.join(DIR,'12-25-40_4_snapshot_keypoints.json')
    raw_img_json = pd.read_json(file_path)
    img_keypoints_list = raw_img_json.people[0]['pose_keypoints_2d']
    x = img_keypoints_list[0::3]
    posY = img_keypoints_list[1::3]
    y = [-y for y in posY]
    np.save(os.path.join('NumpyDemiPlie', 'DemiSampleSkeletonMatchX.npy'), x)
    np.save(os.path.join('NumpyDemiPlie', 'DemiSampleSkeletonMatchY.npy'), y)
    sc = ax.scatter(x,y,s=10)
    for bone in bones:
        #if((x[bone[0]]==0 and y[bone[0]]==0) or(x[bone[1]]==0 and y[bone[1]]==0)):
            #continue
        ax.plot([x[bone[0]],x[bone[1]]],[y[bone[0]],y[bone[1]]],'orchid')
            
plotSampleSkeleton()

# %%
#Calculate distance vectors
#1 zip the necessary lists - first Mean and stddevPlot Plus
xMeanloaded = np.load('Demi-PlieMeanX.npy')
yMeanloaded = np.load('Demi-PlieMeanY.npy')
MeanTuples = list(zip(xMeanloaded, yMeanloaded))
print(MeanTuples)

stdDevPlusX = np.load(os.path.join('NumpyDemiPlie', 'DemiStdDevPlotPlusX.npy'))
stdDevPlusY = np.load(os.path.join('NumpyDemiPlie', 'DemiStdDevPlotPlusY.npy'))
stdDevPlusTuples = list(zip(stdDevPlusX,stdDevPlusY))
print(stdDevPlusTuples)

longZip = list(zip(MeanTuples,stdDevPlusTuples))
print(longZip)
# Out:
# [(0.5155158757192178, -0.35125850632911426), (0.5160010471806675, -0.4213327813578831), (0.4817091622554661, -0.42157289528193337), (0.4575228089758342, -0.49636281818181793), (0.46730600805523614, -0.5576839551208282), (0.5498836708860758, -0.42049227042577625), (0.5743455500575373, -0.4934064856156506), (0.569278120828539, -0.5560502865362483), (0.5174438929804369, -0.5629636766398157), (0.49434375373993095, -0.5634468193325656), (0.4637104706559263, -0.6725725512082857), (0.5029431196777906, -0.7672708400460314), (0.5406276156501733, -0.5625846121979283), (0.5737425753739934, -0.6704106570771001), (0.5373136915995393, -0.7671064729574226), (0.5079209712313003, -0.3437651518987339), (0.5228437629459146, -0.3431917997698504), (0.4980208250863058, -0.35484782163406225), (0.5331130046029917, -0.35389451553509743), (0.5656410483314159, -0.7916608642117383), (0.5626386455696208, -0.7821479620253148), (0.5291120057537394, -0.7747197042577675), (0.4762193199079402, -0.7920932600690452), (0.4765224039125427, -0.785173208285385), (0.5106146283084011, -0.7747748872266977)]
# [(0.5407084359271016, -0.31743983525314323), (0.5414228234363112, -0.3900594591513341), (0.5067353856526907, -0.39049157379509736), (0.48280799347281617, -0.46757182700819677), (0.49302760578900934, -0.5272932114128576), (0.5762124159426791, -0.3891567574918675), (0.6028309232714321, -0.46417168258641994), (0.5972804176162573, -0.5240729749657238), (0.5430082041628121, -0.5330305850686236), (0.5194747793999134, -0.5338716028524), (0.487468068028167, -0.6439800355967396), (0.5284643597292549, -0.7354986503030645), (0.5667857766709781, -0.5324583949218294), (0.6030495721406296, -0.6411138798920075), (0.5634024428083495, -0.7355002548777069), (0.5334124907075889, -0.31018324124254554), (0.5486468825362123, -0.30926771627977084), (0.5230357654974124, -0.32093664878244793), (0.5588278874261853, -0.3196337137754263), (0.5935224132330624, -0.7604226407062142), (0.605437493718163, -0.7268333414919852), (0.5546104300775385, -0.742775045600393), (0.5018078471360103, -0.7604477784297791), (0.5025017991905438, -0.7539293421925009), (0.5363855932927957, -0.7426387975488216)]
# [((0.5155158757192178, -0.35125850632911426), (0.5407084359271016, -0.31743983525314323)), ((0.5160010471806675, -0.4213327813578831), (0.5414228234363112, -0.3900594591513341)), ((0.4817091622554661, -0.42157289528193337), (0.5067353856526907, -0.39049157379509736)), ((0.4575228089758342, -0.49636281818181793), (0.48280799347281617, -0.46757182700819677)), ((0.46730600805523614, -0.5576839551208282), (0.49302760578900934, -0.5272932114128576)), ((0.5498836708860758, -0.42049227042577625), (0.5762124159426791, -0.3891567574918675)), ((0.5743455500575373, -0.4934064856156506), (0.6028309232714321, -0.46417168258641994)), ((0.569278120828539, -0.5560502865362483), (0.5972804176162573, -0.5240729749657238)), ((0.5174438929804369, -0.5629636766398157), (0.5430082041628121, -0.5330305850686236)), ((0.49434375373993095, -0.5634468193325656), (0.5194747793999134, -0.5338716028524)), ((0.4637104706559263, -0.6725725512082857), (0.487468068028167, -0.6439800355967396)), ((0.5029431196777906, -0.7672708400460314), (0.5284643597292549, -0.7354986503030645)), ((0.5406276156501733, -0.5625846121979283), (0.5667857766709781, -0.5324583949218294)), ((0.5737425753739934, -0.6704106570771001), (0.6030495721406296, -0.6411138798920075)), ((0.5373136915995393, -0.7671064729574226), (0.5634024428083495, -0.7355002548777069)), ((0.5079209712313003, -0.3437651518987339), (0.5334124907075889, -0.31018324124254554)), ((0.5228437629459146, -0.3431917997698504), (0.5486468825362123, -0.30926771627977084)), ((0.4980208250863058, -0.35484782163406225), (0.5230357654974124, -0.32093664878244793)), ((0.5331130046029917, -0.35389451553509743), (0.5588278874261853, -0.3196337137754263)), ((0.5656410483314159, -0.7916608642117383), (0.5935224132330624, -0.7604226407062142)), ((0.5626386455696208, -0.7821479620253148), (0.605437493718163, -0.7268333414919852)), ((0.5291120057537394, -0.7747197042577675), (0.5546104300775385, -0.742775045600393)), ((0.4762193199079402, -0.7920932600690452), (0.5018078471360103, -0.7604477784297791)), ((0.4765224039125427, -0.785173208285385), (0.5025017991905438, -0.7539293421925009)), ((0.5106146283084011, -0.7747748872266977), (0.5363855932927957, -0.7426387975488216))]

# %%
#1 Distance vector between Mean skeleton and Std Deviation Skeleton Added:
import math


def calcDistance(x1,y1,x2,y2):
    distance = math.sqrt((x2-x1)**2 + (y2-y1)**2)
    return distance

def calcDistVector(longZipFile, filename):
    distanceVector = []
    for ((x1,y1),(x2,y2)) in longZipFile:
        d = calcDistance(x1,y1,x2,y2)
        print(d)
        distanceVector.append(d)
    np.save(os.path.join('NumpyDemiPlie', filename), distanceVector)


#x1 = mean skeleton x points
#y1 = mean skeleton y points
#x2 = std dev skeleton x points
#y2 = std dev skeleton y points

#1. zip mean x and mean y.
#2. zip std dev x and std dev y
#3. loop and calcultate the distance between each of the points
#4. save to distance vector

# %%
calcDistVector(longZip, 'DistanceStdDevAdded.npy')
# Out:
# 0.04217069602428412
# 0.04030244893088557
# 0.03990439077214243
# 0.038317903489177865
# 0.03981454373845826
# 0.04092819550245009
# 0.04081776813218463
# 0.04250502418145246
# 0.03936399341071344
# 0.0388105897993235
# 0.03717466048127421
# 0.04075298436713017
# 0.03989784900664534
# 0.0414391265944709
# 0.040982629990494075
# 0.04216114667001146
# 0.0426221118814295
# 0.042139232170784476
# 0.04283757387885148
# 0.04187119674143363
# 0.06993889223878384
# 0.040873351461957246
# 0.04069655063863299
# 0.04063383008578813
# 0.041193092819202

# %%
#zip Mean and StdDevMinus:
xMeanloaded = np.load('Demi-PlieMeanX.npy')
yMeanloaded = np.load('Demi-PlieMeanY.npy')
MeanTuples = list(zip(xMeanloaded, yMeanloaded))
print(MeanTuples)

stdDevMinusX = np.load(os.path.join('NumpyDemiPlie', 'DemiStdDevPlotMinusX.npy'))
stdDevMinusY = np.load(os.path.join('NumpyDemiPlie', 'DemiStdDevPlotMinusY.npy'))
stdDevMinusTuples = list(zip(stdDevMinusX,stdDevMinusY))
print(stdDevMinusTuples)

longZipStdDevMinus = list(zip(MeanTuples,stdDevMinusTuples))
print(longZipStdDevMinus)
# Out:
# [(0.5155158757192178, -0.35125850632911426), (0.5160010471806675, -0.4213327813578831), (0.4817091622554661, -0.42157289528193337), (0.4575228089758342, -0.49636281818181793), (0.46730600805523614, -0.5576839551208282), (0.5498836708860758, -0.42049227042577625), (0.5743455500575373, -0.4934064856156506), (0.569278120828539, -0.5560502865362483), (0.5174438929804369, -0.5629636766398157), (0.49434375373993095, -0.5634468193325656), (0.4637104706559263, -0.6725725512082857), (0.5029431196777906, -0.7672708400460314), (0.5406276156501733, -0.5625846121979283), (0.5737425753739934, -0.6704106570771001), (0.5373136915995393, -0.7671064729574226), (0.5079209712313003, -0.3437651518987339), (0.5228437629459146, -0.3431917997698504), (0.4980208250863058, -0.35484782163406225), (0.5331130046029917, -0.35389451553509743), (0.5656410483314159, -0.7916608642117383), (0.5626386455696208, -0.7821479620253148), (0.5291120057537394, -0.7747197042577675), (0.4762193199079402, -0.7920932600690452), (0.4765224039125427, -0.785173208285385), (0.5106146283084011, -0.7747748872266977)]
# [(0.49032331551133385, -0.3850771774050853), (0.4905792709250238, -0.4526061035644321), (0.45668293885824157, -0.4526542167687694), (0.4322376244788522, -0.5251538093554391), (0.44158441032146295, -0.5880746988287989), (0.5235549258294725, -0.451827783359685), (0.5458601768436425, -0.5226412886448812), (0.5412758240408208, -0.5880275981067729), (0.4918795817980616, -0.5928967682110079), (0.4692127280799485, -0.5930220358127312), (0.4399528732836856, -0.7011650668198319), (0.4774218796263264, -0.7990430297889983), (0.5144694546293684, -0.5927108294740272), (0.5444355786073573, -0.6997074342621927), (0.5112249403907292, -0.7987126910371384), (0.48242945175501173, -0.3773470625549223), (0.4970406433556169, -0.37711588325993), (0.4730058846751992, -0.3887589944856766), (0.5073981217797982, -0.38815531729476854), (0.5377596834297694, -0.8228990877172624), (0.5198397974210787, -0.8374625825586444), (0.5036135814299403, -0.806664362915142), (0.45063079267987005, -0.8237387417083114), (0.4505430086345415, -0.816417074378269), (0.48484366332400647, -0.8069109769045739)]
# [((0.5155158757192178, -0.35125850632911426), (0.49032331551133385, -0.3850771774050853)), ((0.5160010471806675, -0.4213327813578831), (0.4905792709250238, -0.4526061035644321)), ((0.4817091622554661, -0.42157289528193337), (0.45668293885824157, -0.4526542167687694)), ((0.4575228089758342, -0.49636281818181793), (0.4322376244788522, -0.5251538093554391)), ((0.46730600805523614, -0.5576839551208282), (0.44158441032146295, -0.5880746988287989)), ((0.5498836708860758, -0.42049227042577625), (0.5235549258294725, -0.451827783359685)), ((0.5743455500575373, -0.4934064856156506), (0.5458601768436425, -0.5226412886448812)), ((0.569278120828539, -0.5560502865362483), (0.5412758240408208, -0.5880275981067729)), ((0.5174438929804369, -0.5629636766398157), (0.4918795817980616, -0.5928967682110079)), ((0.49434375373993095, -0.5634468193325656), (0.4692127280799485, -0.5930220358127312)), ((0.4637104706559263, -0.6725725512082857), (0.4399528732836856, -0.7011650668198319)), ((0.5029431196777906, -0.7672708400460314), (0.4774218796263264, -0.7990430297889983)), ((0.5406276156501733, -0.5625846121979283), (0.5144694546293684, -0.5927108294740272)), ((0.5737425753739934, -0.6704106570771001), (0.5444355786073573, -0.6997074342621927)), ((0.5373136915995393, -0.7671064729574226), (0.5112249403907292, -0.7987126910371384)), ((0.5079209712313003, -0.3437651518987339), (0.48242945175501173, -0.3773470625549223)), ((0.5228437629459146, -0.3431917997698504), (0.4970406433556169, -0.37711588325993)), ((0.4980208250863058, -0.35484782163406225), (0.4730058846751992, -0.3887589944856766)), ((0.5331130046029917, -0.35389451553509743), (0.5073981217797982, -0.38815531729476854)), ((0.5656410483314159, -0.7916608642117383), (0.5377596834297694, -0.8228990877172624)), ((0.5626386455696208, -0.7821479620253148), (0.5198397974210787, -0.8374625825586444)), ((0.5291120057537394, -0.7747197042577675), (0.5036135814299403, -0.806664362915142)), ((0.4762193199079402, -0.7920932600690452), (0.45063079267987005, -0.8237387417083114)), ((0.4765224039125427, -0.785173208285385), (0.4505430086345415, -0.816417074378269)), ((0.5106146283084011, -0.7747748872266977), (0.48484366332400647, -0.8069109769045739))]

# %%
calcDistVector(longZipStdDevMinus, 'DistanceStdDevMinus.npy')
# Out:
# 0.04217069602428415
# 0.0403024489308856
# 0.0399043907721424
# 0.038317903489177865
# 0.03981454373845826
# 0.04092819550245009
# 0.04081776813218463
# 0.04250502418145246
# 0.03936399341071348
# 0.0388105897993235
# 0.03717466048127421
# 0.04075298436713014
# 0.03989784900664534
# 0.0414391265944709
# 0.040982629990494075
# 0.04216114667001146
# 0.04262211188142954
# 0.042139232170784476
# 0.04283757387885148
# 0.04187119674143363
# 0.06993889223878384
# 0.040873351461957246
# 0.04069655063863299
# 0.040633830085788164
# 0.04119309281920203

# %%
# add the two distance vectors together: - actually times two since they are identical.
distanceStdDevAdded = np.load(os.path.join('NumpyDemiPlie', 'DistanceStdDevAdded.npy'))
print(distanceStdDevAdded)
distanceStdDevMinus = np.load(os.path.join('NumpyDemiPlie', 'DistanceStdDevMinus.npy'))
print(distanceStdDevMinus)
#DistanceSumStdDevs = [x + y for x, y in zip(, )]
# Out:
# [0.0421707  0.04030245 0.03990439 0.0383179  0.03981454 0.0409282
#  0.04081777 0.04250502 0.03936399 0.03881059 0.03717466 0.04075298
#  0.03989785 0.04143913 0.04098263 0.04216115 0.04262211 0.04213923
#  0.04283757 0.0418712  0.06993889 0.04087335 0.04069655 0.04063383
#  0.04119309]
# [0.0421707  0.04030245 0.03990439 0.0383179  0.03981454 0.0409282
#  0.04081777 0.04250502 0.03936399 0.03881059 0.03717466 0.04075298
#  0.03989785 0.04143913 0.04098263 0.04216115 0.04262211 0.04213923
#  0.04283757 0.0418712  0.06993889 0.04087335 0.04069655 0.04063383
#  0.04119309]

# %%
DistanceSumStdDevs = [x + y for x, y in zip(distanceStdDevAdded,distanceStdDevMinus)]
print(DistanceSumStdDevs)
np.save(os.path.join('NumpyDemiPlie','DistanceStdDevsDoubled.npy'), DistanceSumStdDevs)
# Out:
# [0.08434139204856828, 0.08060489786177116, 0.07980878154428483, 0.07663580697835573, 0.07962908747691652, 0.08185639100490018, 0.08163553626436926, 0.08501004836290492, 0.07872798682142693, 0.077621179598647, 0.07434932096254843, 0.0815059687342603, 0.07979569801329069, 0.0828782531889418, 0.08196525998098815, 0.08432229334002292, 0.08524422376285903, 0.08427846434156895, 0.08567514775770296, 0.08374239348286726, 0.13987778447756768, 0.08174670292391449, 0.08139310127726598, 0.0812676601715763, 0.08238618563840402]

# %%
#Sample skeleton match
#zip Mean and SampleSkeleton:
xMeanloaded = np.load('Demi-PlieMeanX.npy')
yMeanloaded = np.load('Demi-PlieMeanY.npy')
MeanTuples = list(zip(xMeanloaded, yMeanloaded))
print(MeanTuples)

sampleMatchX = np.load(os.path.join('NumpyDemiPlie', 'DemiSampleSkeletonMatchX.npy'))
sampleMatchY = np.load(os.path.join('NumpyDemiPlie', 'DemiSampleSkeletonMatchY.npy'))
sampleMatchTuples = list(zip(sampleMatchX,sampleMatchY))
print(sampleMatchTuples)

longZipSample = list(zip(MeanTuples,sampleMatchTuples))
print(longZipSample)
# Out:
# [(0.5155158757192178, -0.35125850632911426), (0.5160010471806675, -0.4213327813578831), (0.4817091622554661, -0.42157289528193337), (0.4575228089758342, -0.49636281818181793), (0.46730600805523614, -0.5576839551208282), (0.5498836708860758, -0.42049227042577625), (0.5743455500575373, -0.4934064856156506), (0.569278120828539, -0.5560502865362483), (0.5174438929804369, -0.5629636766398157), (0.49434375373993095, -0.5634468193325656), (0.4637104706559263, -0.6725725512082857), (0.5029431196777906, -0.7672708400460314), (0.5406276156501733, -0.5625846121979283), (0.5737425753739934, -0.6704106570771001), (0.5373136915995393, -0.7671064729574226), (0.5079209712313003, -0.3437651518987339), (0.5228437629459146, -0.3431917997698504), (0.4980208250863058, -0.35484782163406225), (0.5331130046029917, -0.35389451553509743), (0.5656410483314159, -0.7916608642117383), (0.5626386455696208, -0.7821479620253148), (0.5291120057537394, -0.7747197042577675), (0.4762193199079402, -0.7920932600690452), (0.4765224039125427, -0.785173208285385), (0.5106146283084011, -0.7747748872266977)]
# [(0.484853, -0.316996), (0.48488299999999995, -0.38791699999999996), (0.450128, -0.388021), (0.433845, -0.477842), (0.43787699999999996, -0.546048), (0.521602, -0.38528399999999996), (0.535961, -0.47790299999999997), (0.533906, -0.551489), (0.490961, -0.5350389999999999), (0.466395, -0.5351119999999999), (0.439891, -0.671331), (0.47056499999999996, -0.796603), (0.51353, -0.532445), (0.542087, -0.668615), (0.515412, -0.7939539999999999), (0.48070199999999996, -0.311588), (0.49702399999999997, -0.308949), (0.46659000000000006, -0.31983), (0.507354, -0.317255), (0.54822, -0.818441), (0.5462009999999999, -0.813082), (0.505265, -0.804896), (0.43587099999999995, -0.8239609999999999), (0.43790799999999996, -0.8184089999999999), (0.480776, -0.810288)]
# [((0.5155158757192178, -0.35125850632911426), (0.484853, -0.316996)), ((0.5160010471806675, -0.4213327813578831), (0.48488299999999995, -0.38791699999999996)), ((0.4817091622554661, -0.42157289528193337), (0.450128, -0.388021)), ((0.4575228089758342, -0.49636281818181793), (0.433845, -0.477842)), ((0.46730600805523614, -0.5576839551208282), (0.43787699999999996, -0.546048)), ((0.5498836708860758, -0.42049227042577625), (0.521602, -0.38528399999999996)), ((0.5743455500575373, -0.4934064856156506), (0.535961, -0.47790299999999997)), ((0.569278120828539, -0.5560502865362483), (0.533906, -0.551489)), ((0.5174438929804369, -0.5629636766398157), (0.490961, -0.5350389999999999)), ((0.49434375373993095, -0.5634468193325656), (0.466395, -0.5351119999999999)), ((0.4637104706559263, -0.6725725512082857), (0.439891, -0.671331)), ((0.5029431196777906, -0.7672708400460314), (0.47056499999999996, -0.796603)), ((0.5406276156501733, -0.5625846121979283), (0.51353, -0.532445)), ((0.5737425753739934, -0.6704106570771001), (0.542087, -0.668615)), ((0.5373136915995393, -0.7671064729574226), (0.515412, -0.7939539999999999)), ((0.5079209712313003, -0.3437651518987339), (0.48070199999999996, -0.311588)), ((0.5228437629459146, -0.3431917997698504), (0.49702399999999997, -0.308949)), ((0.4980208250863058, -0.35484782163406225), (0.46659000000000006, -0.31983)), ((0.5331130046029917, -0.35389451553509743), (0.507354, -0.317255)), ((0.5656410483314159, -0.7916608642117383), (0.54822, -0.818441)), ((0.5626386455696208, -0.7821479620253148), (0.5462009999999999, -0.813082)), ((0.5291120057537394, -0.7747197042577675), (0.505265, -0.804896)), ((0.4762193199079402, -0.7920932600690452), (0.43587099999999995, -0.8239609999999999)), ((0.4765224039125427, -0.785173208285385), (0.43790799999999996, -0.8184089999999999)), ((0.5106146283084011, -0.7747748872266977), (0.480776, -0.810288))]

# %%
calcDistVector(longZipSample, 'DistanceSampleMatch.npy')
# Out:
# 0.045979683419144914
# 0.045661223199735944
# 0.046077103711234954
# 0.03006092719827606
# 0.03164588388225372
# 0.045160549315557505
# 0.04139724325790632
# 0.035665000585651536
# 0.038485467205836926
# 0.03979943243595868
# 0.023851805628323633
# 0.043688880066151035
# 0.040529951854968015
# 0.03170646364066986
# 0.03464785423692574
# 0.042145480175275654
# 0.04288623898946254
# 0.04705469793337264
# 0.044788172733251745
# 0.03194790443524053
# 0.035030142695851856
# 0.038461519836604986
# 0.05141536509352484
# 0.05094791497616233
# 0.046384533178379636

# %%
#get a non-match skeleton:
DEM_DIR = "D:\openpose-1.5.0-binaries-win64-gpu-python-flir-3d_recommended\openpose-1.5.0-binaries-win64-gpu-python-flir-3d_recommended\DatasetPosePerDancer\Develope\Dancer15"
file_path = os.path.join(DEM_DIR,'12-34-09_4_snapshot_keypoints.json')
raw_img_json = pd.read_json(file_path)
img_keypoints_list = raw_img_json.people[0]['pose_keypoints_2d']
x = img_keypoints_list[0::3]
posY = img_keypoints_list[1::3]
y = [-y for y in posY]
np.save(os.path.join('NumpyDemiPlie', 'DemiSampleSkeletonNonMatchX.npy'), x)
np.save(os.path.join('NumpyDemiPlie', 'DemiSampleSkeletonNonMatchY.npy'), y)

# %%
#zip Mean and SampleNonMatchSkeleton:
xMeanloaded = np.load('Demi-PlieMeanX.npy')
yMeanloaded = np.load('Demi-PlieMeanY.npy')
MeanTuples = list(zip(xMeanloaded, yMeanloaded))
print(MeanTuples)

sampleNonMatchX = np.load(os.path.join('NumpyDemiPlie', 'DemiSampleSkeletonNonMatchX.npy'))
sampleNonMatchY = np.load(os.path.join('NumpyDemiPlie', 'DemiSampleSkeletonNonMatchY.npy'))
sampleNonMatchTuples = list(zip(sampleNonMatchX,sampleNonMatchY))
print(sampleNonMatchTuples)

longZipNonSample = list(zip(MeanTuples,sampleNonMatchTuples))
print(longZipNonSample)
# Out:
# [(0.5155158757192178, -0.35125850632911426), (0.5160010471806675, -0.4213327813578831), (0.4817091622554661, -0.42157289528193337), (0.4575228089758342, -0.49636281818181793), (0.46730600805523614, -0.5576839551208282), (0.5498836708860758, -0.42049227042577625), (0.5743455500575373, -0.4934064856156506), (0.569278120828539, -0.5560502865362483), (0.5174438929804369, -0.5629636766398157), (0.49434375373993095, -0.5634468193325656), (0.4637104706559263, -0.6725725512082857), (0.5029431196777906, -0.7672708400460314), (0.5406276156501733, -0.5625846121979283), (0.5737425753739934, -0.6704106570771001), (0.5373136915995393, -0.7671064729574226), (0.5079209712313003, -0.3437651518987339), (0.5228437629459146, -0.3431917997698504), (0.4980208250863058, -0.35484782163406225), (0.5331130046029917, -0.35389451553509743), (0.5656410483314159, -0.7916608642117383), (0.5626386455696208, -0.7821479620253148), (0.5291120057537394, -0.7747197042577675), (0.4762193199079402, -0.7920932600690452), (0.4765224039125427, -0.785173208285385), (0.5106146283084011, -0.7747748872266977)]
# [(0.482938, -0.328003), (0.482927, -0.385187), (0.464333, -0.385316), (0.433863, -0.317229), (0.43175399999999997, -0.25174799999999997), (0.5113949999999999, -0.38262), (0.5624709999999999, -0.40158000000000005), (0.603324, -0.40424000000000004), (0.495052, -0.513299), (0.480685, -0.513388), (0.495054, -0.63587), (0.501188, -0.7531859999999999), (0.50939, -0.5132559999999999), (0.468529, -0.535169), (0.40105, -0.578754), (0.48073899999999997, -0.317268), (0.495052, -0.317237), (0.46852099999999997, -0.336093), (0.501239, -0.336185), (0.368488, -0.600486), (0.38062799999999997, -0.603262), (0.390901, -0.5787129999999999), (0.47054799999999997, -0.783111), (0.474655, -0.774956), (0.5113679999999999, -0.772104)]
# [((0.5155158757192178, -0.35125850632911426), (0.482938, -0.328003)), ((0.5160010471806675, -0.4213327813578831), (0.482927, -0.385187)), ((0.4817091622554661, -0.42157289528193337), (0.464333, -0.385316)), ((0.4575228089758342, -0.49636281818181793), (0.433863, -0.317229)), ((0.46730600805523614, -0.5576839551208282), (0.43175399999999997, -0.25174799999999997)), ((0.5498836708860758, -0.42049227042577625), (0.5113949999999999, -0.38262)), ((0.5743455500575373, -0.4934064856156506), (0.5624709999999999, -0.40158000000000005)), ((0.569278120828539, -0.5560502865362483), (0.603324, -0.40424000000000004)), ((0.5174438929804369, -0.5629636766398157), (0.495052, -0.513299)), ((0.49434375373993095, -0.5634468193325656), (0.480685, -0.513388)), ((0.4637104706559263, -0.6725725512082857), (0.495054, -0.63587)), ((0.5029431196777906, -0.7672708400460314), (0.501188, -0.7531859999999999)), ((0.5406276156501733, -0.5625846121979283), (0.50939, -0.5132559999999999)), ((0.5737425753739934, -0.6704106570771001), (0.468529, -0.535169)), ((0.5373136915995393, -0.7671064729574226), (0.40105, -0.578754)), ((0.5079209712313003, -0.3437651518987339), (0.48073899999999997, -0.317268)), ((0.5228437629459146, -0.3431917997698504), (0.495052, -0.317237)), ((0.4980208250863058, -0.35484782163406225), (0.46852099999999997, -0.336093)), ((0.5331130046029917, -0.35389451553509743), (0.501239, -0.336185)), ((0.5656410483314159, -0.7916608642117383), (0.368488, -0.600486)), ((0.5626386455696208, -0.7821479620253148), (0.38062799999999997, -0.603262)), ((0.5291120057537394, -0.7747197042577675), (0.390901, -0.5787129999999999)), ((0.4762193199079402, -0.7920932600690452), (0.47054799999999997, -0.783111)), ((0.4765224039125427, -0.785173208285385), (0.474655, -0.774956)), ((0.5106146283084011, -0.7747748872266977), (0.5113679999999999, -0.772104))]

# %%
calcDistVector(longZipNonSample, 'DistanceSampleNonMatch.npy')
# Out:
# 0.04002669810264485
# 0.0489939803126967
# 0.0402056397811721
# 0.18068954418330235
# 0.3079947303322786
# 0.053997098568161886
# 0.09259108164175552
# 0.15558112027741516
# 0.05447914258672582
# 0.05188879403781248
# 0.048264832921493084
# 0.014193772021758715
# 0.05838750391035361
# 0.17134819010406543
# 0.23247461736179068
# 0.03795996073185295
# 0.038026750041713284
# 0.03495687363950228
# 0.03646339410860424
# 0.2746218366640683
# 0.2552020033432193
# 0.23983517303650886
# 0.01062284639097091
# 0.010386459575789967
# 0.0027751049499864988

# %%
#Plot the non-match skeleton:
import os
bones = [[0,1],[1,2],[2,3],[3,4],[1,5],[5,6],[6,7],[1,8],[8,12],[8,9],[9,10],[10,11],[11,24],[11,22],[22,23],[12,13],[13,14],[14,21],[14,19],[19,20],[0,16],[0,15],[15,17],[16,18]]
DEM_DIR = "D:\openpose-1.5.0-binaries-win64-gpu-python-flir-3d_recommended\openpose-1.5.0-binaries-win64-gpu-python-flir-3d_recommended\DatasetPosePerDancer\Develope\Dancer15"

def plotNonSampleSkeleton():
    fig, ax = plt.subplots(1, figsize = (8,8))
    plt.title('Demi-Plie Skeleton Sample Non-Match')
    plt.xlim(0,1)
    plt.ylim(-1,0)
    file_path = os.path.join(DEM_DIR,'12-34-09_4_snapshot_keypoints.json')
    raw_img_json = pd.read_json(file_path)
    img_keypoints_list = raw_img_json.people[0]['pose_keypoints_2d']
    x = img_keypoints_list[0::3]
    posY = img_keypoints_list[1::3]
    y = [-y for y in posY]
    sc = ax.scatter(x,y,s=10)
    for bone in bones:
        #if((x[bone[0]]==0 and y[bone[0]]==0) or(x[bone[1]]==0 and y[bone[1]]==0)):
            #continue
        ax.plot([x[bone[0]],x[bone[1]]],[y[bone[0]],y[bone[1]]],'orchid')
            
plotNonSampleSkeleton()
